# %%
# %load_ext autoreload
# %autoreload 2

    
import os
import random
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from Analysis import Analysis
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ana = Analysis()

# %%
data, data_lot = ana.make_analysis_form()

# %%
data
# Out:
#    Tool/Chamber  feature  target Carrier ID   Wafer ID  \
# 0  EP00018/PM-1        0      10    PFP0073  PFP0073.1
# 1  EP00018/PM-1        1      11    PFP0073  PFP0073.2
# 2  EP00018/PM-2        2      12    PFP0074  PFP0074.3
# 3  EP00019/PM-3        3      13    PFP0075  PFP0075.4
# 4  EP00019/PM-3        4      14    PFP0075  PFP0075.5
# 5  EP00019/PM-4        5      15    PFP0076  PFP0076.6
# 6  EP00020/PM-5        6      16    PFP0077  PFP0077.7
# 7  EP00020/PM-5        7      17    PFP0077  PFP0077.8
# 8  EP00020/PM-5        8      18    PFP0077  PFP0077.9
#
#                Start time        lot_identifier  lot_y  lot_x  wlot_x  wlot_y
# 0 2024-01-01 00:00:00.000  EP00018/PM-1/PFP0073   10.5    0.5    -0.5    -0.5
# 1 2024-01-01 00:00:00.100  EP00018/PM-1/PFP0073   10.5    0.5     0.5     0.5
# 2 2024-01-01 00:00:00.200  EP00018/PM-2/PFP0074   12.0    2.0     0.0     0.0
# 3 2024-01-01 00:00:00.300  EP00019/PM-3/PFP0075   13.5    3.5    -0.5    -0.5
# ...

# %%
ana.get_score()
# Out:
#   parameter  pval   r2  slope  pval_l  r2_l  slope_l  pval_wl  r2_wl  \
# 0   feature   0.0  1.0    1.0     0.0   1.0      1.0      0.0    1.0
#
#    slope_wl class  score
# 0       1.0          1.0

# %%
ana.draw_chart('Tool/Chamber', trend=True)
